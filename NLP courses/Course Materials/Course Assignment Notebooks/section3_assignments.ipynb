# %% [markdown]
# # Text Preprocessing Assignments

# %% [markdown]
# ## 0. Create a New Environment

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
df = pd.read_csv('../Data/childrens_books.csv')
df.head()
import spacy

# %% [markdown]
# ## 1. Text Preprocessing with Pandas

# %% [markdown]
# 1. Read the _childrens_books.csv_ file into a Jupyter Notebook
# 2. Within the Description column:
# * Make all the text lowercase
# * Remove all \xa0 characters
# * Remove all punctuation

# %%
def replace_lower(series):
    output = series.str.lower()
    output = output.str.replace(r'\xa0', '', regex=True)
    output = output.str.replace(r'[^\w\s]','', regex=True)
    return output

# %%
df_data = df.copy()
df_data.head(1)
# Out:
#    Ranking                      Title          Author  Year Rating  \
# 0        1  Where the Wild Things Are  Maurice Sendak  1963   4.25
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                Description
# 0  Where the Wild Things Are follows Max, a young boy who, after being sent to his room for misbehaving, imagines sailing to an island filled with wild creatures. As their king, Max tames the beasts and eventually returns home to find his supper waiting for him. This iconic book explores themes of imagination, adventure, and the complex emotions of childhood, all captured through Sendak's whimsical illustrations and story.

# %%
df_data.Description = replace_lower(df_data.Description)

# %% [markdown]
# ## 2. Text Preprocessing with spaCy

# %% [markdown]
# In addition to the lowercasing and special character removal from the previous assignment, within the cleaned Description column:
# * Tokenize the text
# * Lemmatize the text
# * Remove stop words

# %%
nlp = spacy.load('en_core_web_sm')

# %%
phrase = 'im selling lemons for $5 today'
doc = nlp(phrase)
doc
# Out:
# im selling lemons for $5 today

# %%
[token.text for token in doc]
# Out:
# ['i', 'm', 'selling', 'lemons', 'for', '$', '5', 'today']

# %%
# normalize the languages to base form 
[token.lemma_ for token in doc]
# Out:
# ['I', 'm', 'sell', 'lemon', 'for', '$', '5', 'today']

# %%
# stop words -> words without any significant meaning 

norm = [token.lemma_ for token in doc if not token.is_stop]
norm
# Out:
# ['m', 'sell', 'lemon', '$', '5', 'today']

# %%
#speech tagging 

pos = [(token.text, token.pos_) for token in doc]
pos
# Out:
# [('i', 'PRON'),
#  ('m', 'AUX'),
#  ('selling', 'VERB'),
#  ('lemons', 'NOUN'),
#  ('for', 'ADP'),
#  ('$', 'SYM'),
#  ('5', 'NUM'),
#  ('today', 'NOUN')]

# %%
phrase = df_data.Description[0]
phrase
# Out:
# 'where the wild things arefollows max a young boy who after being sent to his room for misbehaving imagines sailing to an island filled with wild creatures as their king max tames the beasts and eventually returns home to find his supper waiting for him this iconic book explores themes of imagination adventure and the complex emotions of childhood all captured through sendaks whimsical illustrations and story'

# %%
doc = nlp(phrase)

# %%
# tokenize

[token for token in doc]
# Out:
# [where,
#  the,
#  wild,
#  things,
#  arefollows,
#  max,
#  a,
#  young,
#  boy,
#  who,
#  after,
#  being,
#  sent,
#  to,
#  his,
#  room,
#  for,
#  misbehaving,
#  imagines,
#  sailing,
#  to,
#  an,
#  island,
#  filled,
#  with,
#  wild,
#  creatures,
#  as,
#  their,
#  king,
#  max,
#  tames,
#  the,
#  beasts,
#  and,
#  eventually,
#  returns,
#  home,
#  to,
#  find,
#  his,
#  supper,
#  waiting,
#  for,
#  him,
#  this,
#  iconic,
#  book,
#  explores,
#  themes,
#  of,
#  imagination,
#  adventure,
#  and,
#  the,
#  complex,
#  emotions,
#  of,
#  childhood,
#  all,
#  captured,
#  through,
#  sendaks,
#  whimsical,
#  illustrations,
#  and,
#  story]

# %%
[token.text for token in doc]
# Out:
# ['where',
#  'the',
#  'wild',
#  'things',
#  'arefollows',
#  'max',
#  'a',
#  'young',
#  'boy',
#  'who',
#  'after',
#  'being',
#  'sent',
#  'to',
#  'his',
#  'room',
#  'for',
#  'misbehaving',
#  'imagines',
#  'sailing',
#  'to',
#  'an',
#  'island',
#  'filled',
#  'with',
#  'wild',
#  'creatures',
#  'as',
#  'their',
#  'king',
#  'max',
#  'tames',
#  'the',
#  'beasts',
#  'and',
#  'eventually',
#  'returns',
#  'home',
#  'to',
#  'find',
#  'his',
#  'supper',
#  'waiting',
#  'for',
#  'him',
#  'this',
#  'iconic',
#  'book',
#  'explores',
#  'themes',
#  'of',
#  'imagination',
#  'adventure',
#  'and',
#  'the',
#  'complex',
#  'emotions',
#  'of',
#  'childhood',
#  'all',
#  'captured',
#  'through',
#  'sendaks',
#  'whimsical',
#  'illustrations',
#  'and',
#  'story']

# %%
[token.lemma_ for token in doc]
# Out:
# ['where',
#  'the',
#  'wild',
#  'thing',
#  'arefollow',
#  'max',
#  'a',
#  'young',
#  'boy',
#  'who',
#  'after',
#  'be',
#  'send',
#  'to',
#  'his',
#  'room',
#  'for',
#  'misbehave',
#  'imago',
#  'sail',
#  'to',
#  'an',
#  'island',
#  'fill',
#  'with',
#  'wild',
#  'creature',
#  'as',
#  'their',
#  'king',
#  'max',
#  'tame',
#  'the',
#  'beast',
#  'and',
#  'eventually',
#  'return',
#  'home',
#  'to',
#  'find',
#  'his',
#  'supper',
#  'wait',
#  'for',
#  'he',
#  'this',
#  'iconic',
#  'book',
#  'explore',
#  'theme',
#  'of',
#  'imagination',
#  'adventure',
#  'and',
#  'the',
#  'complex',
#  'emotion',
#  'of',
#  'childhood',
#  'all',
#  'capture',
#  'through',
#  'sendak',
#  'whimsical',
#  'illustration',
#  'and',
#  'story']

# %%
list(nlp.Defaults.stop_words)[:10]
# Out:
# ['twenty',
#  'to',
#  'becoming',
#  'mostly',
#  'within',
#  'few',
#  'any',
#  'both',
#  'be',
#  'besides']

# %%
norm = [token.lemma_ for token in doc if not token.is_stop ]

# %%
' '.join(norm)
# Out:
# 'wild thing arefollow max young boy send room misbehave imago sail island fill wild creature king max tame beast eventually return home find supper wait iconic book explore theme imagination adventure complex emotion childhood capture sendak whimsical illustration story'

# %%
def token_lemma_nonstop(text):
    doc = nlp(text)
    norm = [token.lemma_ for token in doc if not token.is_stop]
    output = ' '.join(norm)
    return output

# %%
# use apply to apply to the whole data frame
replace_lower(df_data.Description).apply(token_lemma_nonstop)
# Out:
# 0                                   wild thing arefollow max young boy send room misbehave imago sail island fill wild creature king max tame beast eventually return home find supper wait iconic book explore theme imagination adventure complex emotion childhood capture sendak whimsical illustration story
# 1                     hungry caterpillartell story caterpillar eat variety food eventually butterfly eric carles use colorful collage illustration rhythmic text book beloved classic young reader simple engaging story introduce child day week counting concept metamorphosis staple early childhood education
# 2                                                   give treeis touching bittersweet story tree give boy course life boy grow take tree tree continue little left silverstein minimalist text illustration convey deep theme unconditional love selflessness passage time spark discussion relationship sacrifice
# 3             ingreen eggs ham samiam try convince reluctant character try dish green egg ham despite resistance repetition rhyme dr seusss classic story open new experience encourage child adventurous try thing outside comfort zone playful illustration humorous dialogue fun educational read young reader
# 4                                    goodnight mooni gentle rhythmic bedtime story little bunny say goodnight room moon quiet old lady whispering hush repetitive structure comfort tone ideal young child simple illustration clement hurd complement soothe nature story make beloved classic sleeptime reading
#                                                                                                                                                          ...
# 95                             stone soupi classic folktale retold jon j muth soldier arrive village claim soup stone villager initially hesitant eventually contribute ingredient pot create delicious meal story heartwarming lesson share community cooperation enhance muth beautiful watercolor illustration
# 96                light atticis collection quirky poem illustration shel silverstein explore wide range topic wit humor imagination poem funny thoughtful absurd carry sense wonder creativity silverstein distinctive voice whimsical illustration book timeless collection continue entertain child adult alike
# 97                      harry potter prisoner azkabanis book theharry potterserie harry return hogwart year uncover secret past arrival mysterious sirius black harry navigate dark truth face fear thrilling installment explore theme loyalty friendship identity mark turning point magical world harry potter
# 98                         harry potter chamber secretsis second book theharry potterserie harry return hogwart second year uncover hidden chamber school mysterious event unfold harry friend ron hermione uncover dark secret school past theme courage friendship stand s right explore grip magical adventure
# 99    billy goat gruffis retelling classic norwegian fairy tale goat outwit greedy troll cross bridge reach green pasture goat come clever strategy trick troll teach child lesson teamwork bravery cleverness galdone illustration simple rhythmic text bring tale life way accessible entertaining young reader
# Name: Description, Length: 100, dtype: str

# %%
# speech tagging 
phrase2 = replace_lower(df_data.Description).apply(token_lemma_nonstop)[0]

# %%
doc2 = nlp(phrase2)
doc2
# Out:
# wild thing arefollow max young boy send room misbehave imago sail island fill wild creature king max tame beast eventually return home find supper wait iconic book explore theme imagination adventure complex emotion childhood capture sendak whimsical illustration story

# %%
nouns = [token.text for token in doc2 if token.pos_ in ['NOUN', 'PROPN']]
' '.join(nouns)
# Out:
# 'thing arefollow max boy room misbehave imago sail island fill creature king max tame beast home find supper book theme imagination adventure emotion childhood sendak illustration story'

# %%
def filter_pos(text, pos_list=['NOUN', 'PROPN']):
    doc = nlp(text)
    output = [token.text for token in doc if token.pos_ in pos_list]
    output = ' '.join(output)
    return output

# %%
replace_lower(df_data.Description).apply(token_lemma_nonstop).apply(filter_pos)
# Out:
# 0                          thing arefollow max boy room misbehave imago sail island fill creature king max tame beast home find supper book theme imagination adventure emotion childhood sendak illustration story
# 1                              caterpillartell story caterpillar eat variety food eric carles collage illustration text book reader story introduce child day week concept metamorphosis staple childhood education
# 2                                                               story tree boy course life boy tree tree silverstein text illustration theme love selflessness passage time spark discussion relationship sacrifice
# 3                                          ingreen eggs ham samiam convince character dish egg ham resistance repetition rhyme dr seusss story experience child thing comfort zone illustration dialogue fun reader
# 4                                      bedtime story little bunny goodnight room moon lady whispering structure comfort tone ideal child illustration clement hurd complement soothe nature story sleeptime reading
#                                                                                                           ...
# 95                   stone soupi folktale retold jon j muth soldier arrive village claim soup stone villager ingredient pot meal story heartwarming lesson share community cooperation muth watercolor illustration
# 96                                 light atticis collection quirky poem illustration shel silverstein range topic wit humor imagination poem sense wonder creativity voice illustration book collection child adult
# 97    harry potter prisoner azkabanis book theharry potterserie harry return hogwart year arrival sirius black harry truth fear installment explore theme loyalty friendship identity mark point world harry potter
# 98            harry potter chamber secretsis book theharry potterserie harry return hogwart year hidden chamber school event harry friend ron hermione school theme courage friendship stand explore grip adventure
# 99                                               billy goat gruffis fairy tale goat outwit troll cross bridge pasture goat strategy trick troll child lesson teamwork bravery galdone illustration text life reader
# Name: Description, Length: 100, dtype: str

# %% [markdown]
# ## NLP PIPELINE

# %%
def replace_lower(series):
    output = series.str.lower()
    output = output.str.replace(r'\xa0', '', regex=True)
    output = output.str.replace(r'[^\w\s]','', regex=True)
    return output

def token_lemma_nonstop(text):
    doc = nlp(text)
    norm = [token.lemma_ for token in doc if not token.is_stop]
    output = ' '.join(norm)
    return output

def filter_pos(text, pos_list=['NOUN', 'PROPN']):
    doc = nlp(text)
    output = [token.text for token in doc if token.pos_ in pos_list]
    output = ' '.join(output)
    return output

# %%
def nlp_pipeline(series):
    output = replace_lower(series)
    output = output.apply(token_lemma_nonstop)
    output = output.apply(filter_pos)
    return output

# %% [markdown]
# ## 3. Count Vectorizer

# %% [markdown]
# 1. Vectorize the cleaned and normalized text using Count Vectorizer with the default parameters
# 2. Modify the Count Vectorizer parameters to reduce the number of columns:
# * Remove stop words
# * Set a minimum document frequency of 10%
# 3. Use the updated Count Vectorizer to identify the:
# * Top 10 most common terms
# * Top 10 least common terms that appear in at least 10% of the documents
# 4. Create a horizontal bar chart of the top 10 most common terms

# %% [markdown]
# ## 4. TF-IDF Vectorizer

# %% [markdown]
# 1. Vectorize the cleaned and normalized text using TF-IDF Vectorizer with the default parameters
# 2. Modify the TF-IDF Vectorizer parameters to reduce the number of columns:
# * Remove stop words
# * Set a minimum document frequency of 10%
# * Set a maximum document frequency of 50%
# 3. Using the updated TF-IDF Vectorizer, create a  horizontal bar chart of the top 10 most highly weighted terms
# 4. Compare the Count Vectorizer bar chart from the previous assignment with the TF-IDF Vectorizer bar chart and note the differences in the top term lists
